# %%
import pandas as pd

# %%
reviews = pd.read_csv('/Users/dinarakarakulova/Documents/Msc_CoBi/Machine Learning/Project_ML_SS2025-2/Data/reviews.csv.gz', compression= 'gzip')

# %%
listings = pd.read_csv('/Users/dinarakarakulova/Documents/Msc_CoBi/Machine Learning/Project_ML_SS2025-2/Preprocessing/listings_cleaned.csv')

# %%
listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'source', 'name', 'description',
#        'picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
# ...

# %%
listings['id']
# Out:
# 0                      6624
# 1                     27116
# 2                     44527
# 3                     47383
# 4                     49656
#                ...
# 4556    1349238669235464370
# 4557    1349336283390581473
# 4558    1349404120470429129
# 4559    1363032277989558235
# 4560    1358916128017498979
# Name: id, Length: 4561, dtype: int64

# %%
a = listings.loc[listings['id'] == 6624]
b = a[['id','price']]
b
# Out:
#      id  price
# 0  6624  227.0

# %%
id_prices = listings[['id', 'price']]
id_prices = id_prices.rename(columns={'id': 'listing_id'})
id_prices
# Out:
#                listing_id  price
# 0                    6624  227.0
# 1                   27116  187.0
# 2                   44527  391.0
# 3                   47383   98.0
# 4                   49656  101.0
# ...                   ...    ...
# 4556  1349238669235464370   26.0
# 4557  1349336283390581473   50.0
# 4558  1349404120470429129  151.0
# 4559  1363032277989558235   85.0
# 4560  1358916128017498979   73.0
#
# [4561 rows x 2 columns]

# %%
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id        reviewer_name  \
# 0        6624   581824  2011-09-29      1189528             Lawrence
# 1        6624   654634  2011-10-23        71925          Helen & Rob
# 2        6624  2774855  2012-11-01      1570645                Linda
# 3        6624  2987711  2012-11-28      4041941               Joseph
# 4        6624  5385172  2013-06-27       743472  Steve And Serenella
#
#                                             comments
# 0  The apartment was wonderful and despite our de...
# 1  This is truly the best place to be. A very nic...
# 2  This was a great location and such wonderful p...
# 3  Your apartment gave us a home in Venice...maki...
# 4  Very nicely and tastefully furnished, clean   ...

# %%
reviews = reviews.join(id_prices.set_index('listing_id'), on='listing_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 reviews = reviews.join(id_prices.set_index('listing_id'), on='listing_id')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/core/frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
# ...

# %%
reviews
# Out:
#                  listing_id                   id        date  reviewer_id  \
# 0                      6624               581824  2011-09-29      1189528
# 1                      6624               654634  2011-10-23        71925
# 2                      6624              2774855  2012-11-01      1570645
# 3                      6624              2987711  2012-11-28      4041941
# 4                      6624              5385172  2013-06-27       743472
# ...                     ...                  ...         ...          ...
# 758703  1358916128017498979  1364407866305945786  2025-02-25    363237950
# 758704  1358916128017498979  1366653682781719889  2025-02-28     37316223
# 758705  1358916128017498979  1367342365923193755  2025-03-01    651247976
# 758706  1361599240863979345  1362993430149075671  2025-02-23    680169572
# 758707  1363032277989558235  1366663268894426098  2025-02-28    114000747
#
#               reviewer_name                                           comments
# ...

# %%
reviews.to_csv('reviews_priced.csv', index = False)

# %%
r = pd.read_csv('/Users/dinarakarakulova/Documents/Msc_CoBi/Machine Learning/Project_ML_SS2025-2/Data/reviews_priced.csv')

# %%
r.head()
# Out:
#    listing_id       id        date  reviewer_id        reviewer_name  \
# 0        6624   581824  2011-09-29      1189528             Lawrence
# 1        6624   654634  2011-10-23        71925          Helen & Rob
# 2        6624  2774855  2012-11-01      1570645                Linda
# 3        6624  2987711  2012-11-28      4041941               Joseph
# 4        6624  5385172  2013-06-27       743472  Steve And Serenella
#
#                                             comments
# 0  The apartment was wonderful and despite our de...
# 1  This is truly the best place to be. A very nic...
# 2  This was a great location and such wonderful p...
# 3  Your apartment gave us a home in Venice...maki...
# 4  Very nicely and tastefully furnished, clean   ...
